# %% [markdown]
# <a href="https://colab.research.google.com/github/Sha-98/Data-Science-Masters/blob/main/Python_Assignment_16Sept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Assignment

# %% [markdown]
# 1. Who developed Python Programming Language?

# %% [markdown]
# Answer: Guido van Rossum developed the python programming language.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Which type of Programming does Python support?
#
# Answer: Python is an interpreted programming language, supporting object-oriented, structured, and functional programming.

# %% [markdown]
# 3. Is Python case sensitive when dealing with identifiers?

# %% [markdown]
# Answer: Yes, Python is case sensitive when dealing with Identifiers

# %% [markdown]
# 4. What is the correct extension of the Python file?

# %% [markdown]
# Answer: Python is a general-purpose coding language—which means that, unlike HTML, CSS, and JavaScript, it can be used for other types of programming and software development besides web development. That includes back end development, software development, data science and writing system scripts among other things. Python file extensions are
#
# 1. .py
# 2. .pyi
# 3. .pyc
# 4. .pyd
# 5. .pyo
# 6. .pyw
# 7. .pyz
#
# Out of these, the most widely known python file extension is ".py".

# %% [markdown]
# 5. Is Python code compiled or interpreted?

# %% [markdown]
# Answer: Python is an interpreted language, which means the source code of a Python program is converted into bytecode that is then executed by the Python virtual machine.

# %% [markdown]
# 6. Name a few blocks of code used to define in Python language?

# %% [markdown]
# Answer: In computer programming, a block or code block or block of code is a lexical structure of source code which is grouped together. Blocks consist of one or more declarations and statements.
#
# In python also, a python program is constructed from code blocks. A block is a piece of Python program text that is executed as a unit. The following are some blocks in python:
#
# 1. a module,
# 2. a function body, and
# 3. a class definition.

# %% [markdown]
# 7. State a character used to give single-line comments in Python?

# %% [markdown]
# Answer: Comments in Python are identified with a hash symbol, "#"

# %% [markdown]
# 8. Mention functions which can help us to find the version of python that we are currently working on?

# %% [markdown]
# Answer: We can use the built-in 'sys.version' method to check the version of Python that is currently being used.

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]

# %% [markdown]
# 9. Python supports the creation of anonymous functions at runtime, using a construct called

# %% [markdown]
# Answer: Lambda

# %% [markdown]
# 10. What does pip stand for python?

# %% [markdown]
# Answer: Preferred Installer Program

# %% [markdown]
# 11. Mention a few built-in functions in python?

# %% [markdown]
# Answer: Some of the built-in function in python can be listed below:
#
# 1. print( )
# 2. type( )
# 3. input( )
# 4. abs( )
# 5. pow( )
# 6. dir( )
# 7. sorted( )
# 8. max( )

# %% [markdown]
# 12. What is the maximum possible length of an identifier in Python?

# %% [markdown]
# Answer: An identifier can have a maximum length of 79 characters in Python.

# %% [markdown]
# 13. What are the benefits of using Python?

# %% [markdown]
# Answer: Some of many benefits of using Python language is listed below.
#
# 1. Presence of third-party modules
# 2. Extensive support libraries(NumPy for numerical calculations, Pandas for data analytics, etc.)
# 3. Open source and large active community base
# 4. Versatile, Easy to read, learn and write
# 5. User-friendly data structures
# 6. High-level language
# 7. Dynamically typed language(No need to mention data type based on the value assigned, it takes data type)
# 8. Object-Oriented and Procedural  Programming language
# 9. Portable and Interactive
# 10. Ideal for prototypes – provide more functionality with less coding

# %% [markdown]
# 14. How is memory managed in Python?

# %% [markdown]
# Answer: The Python memory is primarily managed by Python private heap space. All Python objects and data structures are located in a private heap. The programmer does not have access to this private heap and interpreter takes care of this Python private heap.

# %% [markdown]
# 15. How to install Python on Windows and set path variables?

# %% [markdown]
# Answer: Below are the steps we must take to add python to our PATH variable.
#
# 1. First, we must find the directory where we installed Python. A typical installation would have the following path,
# "C:\Users\MyUserName\AppData\Local\Programs\Python\Python310"
#
# 2. Now, we will need to add this to the PATH variable, we right click on "This PC" and go to "Properties".
#
# 3. Then, we click on the "Advanced system settings" in the menu on the left.going
#
# 4. In the bottom right, we can see a button labeled "Environment Variables". We will click on it to open another window to edit these variables.
#
# 5. Now, we select the "Path variable" in the "System variables" section and click "Edit". The next screen will show all the directories currently part of the PATH variable.
#
# 6. Another window opens up where we can see all the paths for the currently configured system variables. To add a new path for our Python program, we will click on the "New" button on the right side and paste the path in Step 1
#
# 7. We have successfully added the path for our Python program to our system's environment variables. The best practice is to restart the system afterward for the change to occur.
#
# 8. Now, we can verify if the PATH variable was configured correctly by opening up the terminal and entering the command python --version.

# %% [markdown]
# 16. Is indentation required in python?

# %% [markdown]
# Answer: Indentation is mandatory in python to define the blocks of statements. It is preferred to use whitespaces instead of tabs to indent in python. Python uses four spaces as default indentation spaces.
